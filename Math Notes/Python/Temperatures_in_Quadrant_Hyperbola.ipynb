# %% [markdown]
# # Steady Temperatures in a Half Plane

# %%
import numpy as np
import matplotlib as mp
import matplotlib.pyplot as plt

from matplotlib import cycler
from IPython.display import Math, display

# %config InlineBackend.figure_format = 'pdf'

# %%
def func(x, c):
    f = x**2/(np.sin(c))**2 - 1
    s = np.sqrt(f)
    P = s * np.cos(c)
    N = -P 
    Y = np.append(P, np.flip(N), axis=0)
    X = np.append(x, np.flip(x), axis=0)
    return Y, X

def graph(x, c_start, c_end, c_step):
    c = np.arange(c_start, c_end, c_step)
    n = np.shape(c)[0]
    
    fig, ax = plt.subplots(1, 1)
    
    for i in range(1, n, 1):
        Y, X = func(x, c[i])
        ax.plot(X, Y, 
                label='$u = {0:1.0f} \pi /{1:1.0f}$'.format(i, (n-1)*2), 
                c=(i/10, i/10, i/10))
        
    ax.axis('equal')
    ax.set_title(r'Hyperbola $\frac{x^2}{\sin^2(u)} - \frac{y^2}{\cos^2(u)} = 1$, for $u \in (0, \frac{\pi}{2})$')
    ax.set_ylim(-1, 1)
    ax.set_xlim(-2, 4)
    ax.set_xlabel("$x$")
    ax.set_ylabel("$y$")
    ax.legend(loc='upper right')
    plt.savefig('Temperaturues_in_Quadrant_Hyperbola.pdf', format='pdf',
        transparent=False, bbox_inches=None, pad_inches=0.1, metadata=None)
    plt.show()

# %%
x = np.arange(-2, 4, 0.0001)

graph(x, 0, np.pi/2+np.pi/16, np.pi/16)
# Out:
# /Users/kev/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/kev/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/kev/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/kev/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/kev/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sqrt
# ...
